# %%
import matplotlib.pyplot as plt
import numpy as np
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., height, '%.2f' % height, ha='center', va='bottom', fontsize=8)

# Dữ liệu
methods = ['Euclide','KNN','SVC', 'LDA', 'LR']
pca_acc = [0.9998158379373848,0.9998158379373848,0.9605893186003683,0.9766114180478821,0.9994475138121548]
lle_acc = [0.9996316758747698,0.9996316758747698,0.9622467771639043,0.9854511970534071,0.994843462246777]
kpca_acc = [0.9998158379373848,0.9998158379373848,0.9639042357274402,0.9769797421731123,0.9994475138121548]
ipca_acc = [0.9996316758747698,0.9992633517495395,0.9637200736648251,0.978268876611418,0.9992633517495395]
#Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(10, 6))


 #Vẽ từng cột với màu sắc tương ứng
bar_width = 0.2
index = np.arange(len(methods))
opacity = 0.8

rects1 = ax.bar(index, pca_acc, bar_width, alpha=opacity,label='PCA')
rects2 = ax.bar(index + bar_width, lle_acc, bar_width, alpha=opacity, label='LLE')
rects3 = ax.bar(index + 2 * bar_width, kpca_acc, bar_width, alpha=opacity,label='KPCA')
rects4 = ax.bar(index + 3 * bar_width, ipca_acc, bar_width, alpha=opacity, label='IPCA')

rects1[0].set_facecolor('gold')
rects1[1].set_facecolor('lightgray')
rects1[2].set_facecolor('lightgray')
rects1[3].set_facecolor('lightgray')
rects1[4].set_facecolor('gold')
rects2[0].set_facecolor('lightgray')
rects2[1].set_facecolor('lightgray')
rects2[2].set_facecolor('lightgray')
rects2[3].set_facecolor('gold')
rects2[4].set_facecolor('lightgray')
rects3[0].set_facecolor('lightgray')
rects3[1].set_facecolor('gold')
rects3[2].set_facecolor('gold')
rects3[3].set_facecolor('lightgray')
rects3[4].set_facecolor('lightgray')
rects4[0].set_facecolor('lightgray')
rects4[1].set_facecolor('lightgray')
rects4[2].set_facecolor('lightgray')
rects4[3].set_facecolor('lightgray')
rects4[4].set_facecolor('lightgray')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

plt.xlabel('Methods')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison by Methods and Dimensionality Reduction Techniques in Set 2')
plt.xticks(index + 1.5 * bar_width, methods)
plt.tight_layout()
plt.text(-0.002, 0.6, 'PCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(1.4, 0.6, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(2.4, 0.6, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(3.2, 0.6, 'LLE', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(4.002, 0.6, 'PCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
# Tùy chỉnh định dạng số trục y
ax.set_ylim([0, 1.2])  # Giới hạn trục y từ 0 đến 1
ax.yaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục y
ax.xaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục x


plt.show()

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., height, '%.2f' % height, ha='center', va='bottom', fontsize=8)

# Dữ liệu
methods = ['Euclide','KNN','SVC', 'LDA', 'LR']
pca_acc = [0.11060151060151062,0.10182910182910183,0.10790108290108291,0.09643052143052144,0.09306351806351806]
lle_acc = [0.08834288834288835,0.09508372008372008,0.06339066339066339,0.10653835653835653,0.0714782964782964]
kpca_acc = [0.1106015106015106,0.10385157885157885,0.10857220857220858,0.10047320047320048,0.09373464373464373]
ipca_acc = [0.12272499772499774,0.10518018018018019,0.10113750113750113,0.09508372008372008,0.10046865046865047]
#Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(10, 6))


 #Vẽ từng cột với màu sắc tương ứng
bar_width = 0.2
index = np.arange(len(methods))
opacity = 0.8

rects1 = ax.bar(index, pca_acc, bar_width, alpha=opacity,label='PCA')
rects2 = ax.bar(index + bar_width, lle_acc, bar_width, alpha=opacity, label='LLE')
rects3 = ax.bar(index + 2 * bar_width, kpca_acc, bar_width, alpha=opacity,label='KPCA')
rects4 = ax.bar(index + 3 * bar_width, ipca_acc, bar_width, alpha=opacity, label='IPCA')

rects1[0].set_facecolor('lightgray')
rects1[1].set_facecolor('lightgray')
rects1[2].set_facecolor('lightgray')
rects1[3].set_facecolor('lightgray')
rects1[4].set_facecolor('lightgray')
rects2[0].set_facecolor('lightgray')
rects2[1].set_facecolor('lightgray')
rects2[2].set_facecolor('lightgray')
rects2[3].set_facecolor('gold')
rects2[4].set_facecolor('lightgray')
rects3[0].set_facecolor('lightgray')
rects3[1].set_facecolor('lightgray')
rects3[2].set_facecolor('gold')
rects3[3].set_facecolor('lightgray')
rects3[4].set_facecolor('lightgray')
rects4[0].set_facecolor('gold')
rects4[1].set_facecolor('gold')
rects4[2].set_facecolor('lightgray')
rects4[3].set_facecolor('lightgray')
rects4[4].set_facecolor('gold')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

plt.xlabel('Methods')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison by Methods and Dimensionality Reduction Techniques in Set 3')
plt.xticks(index + 1.5 * bar_width, methods)
plt.tight_layout()
plt.text(0.6, 0.075, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(1.6, 0.075, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(2.4, 0.075, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(3.2, 0.075, 'LLE', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(4.6, 0.075, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
# Tùy chỉnh định dạng số trục y
ax.set_ylim([0, 0.2])  # Giới hạn trục y từ 0 đến 1
ax.yaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục y
ax.xaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục x


plt.show()

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., height, '%.2f' % height, ha='center', va='bottom', fontsize=8)

# Dữ liệu
methods = ['Euclide', 'KNN', 'SVC', 'LDA', 'LR']
pca_acc = [0.3540061006609049, 0.3183807829181494, 0.42879257752923233, 0.4992882562277581, 0.38247076766649724]
lle_acc = [0.29416115912557195, 0.2606863243518048, 0.2799161159125572, 0.31199034062023384, 0.32124809354346723]
kpca_acc = [0.3540035587188612, 0.3176614133197763, 0.43592018301982716, 0.5099669547534316, 0.37605744789018813]
ipca_acc = [0.3831698017285206, 0.3318861209964413, 0.4309049313675648, 0.5106786985256736, 0.4771936959837316]

#Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(10, 6))


 #Vẽ từng cột với màu sắc tương ứng
bar_width = 0.2
index = np.arange(len(methods))
opacity = 0.8

rects1 = ax.bar(index, pca_acc, bar_width, alpha=opacity,label='PCA')
rects2 = ax.bar(index + bar_width, lle_acc, bar_width, alpha=opacity, label='LLE')
rects3 = ax.bar(index + 2 * bar_width, kpca_acc, bar_width, alpha=opacity,label='KPCA')
rects4 = ax.bar(index + 3 * bar_width, ipca_acc, bar_width, alpha=opacity, label='IPCA')

rects1[0].set_facecolor('lightgray')
rects1[1].set_facecolor('lightgray')
rects1[2].set_facecolor('lightgray')
rects1[3].set_facecolor('lightgray')
rects1[4].set_facecolor('lightgray')
rects2[0].set_facecolor('lightgray')
rects2[1].set_facecolor('lightgray')
rects2[2].set_facecolor('lightgray')
rects2[3].set_facecolor('lightgray')
rects2[4].set_facecolor('lightgray')
rects3[0].set_facecolor('lightgray')
rects3[1].set_facecolor('lightgray')
rects3[2].set_facecolor('gold')
rects3[3].set_facecolor('lightgray')
rects3[4].set_facecolor('lightgray')
rects4[0].set_facecolor('gold')
rects4[1].set_facecolor('gold')
rects4[2].set_facecolor('lightgray')
rects4[3].set_facecolor('gold')
rects4[4].set_facecolor('gold')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

plt.xlabel('Methods')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison by Methods and Dimensionality Reduction Techniques in Set 3(Grey)')
plt.xticks(index + 1.5 * bar_width, methods)
plt.tight_layout()
plt.text(0.6, 0.2, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(1.6, 0.2, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(2.4, 0.2, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(3.6, 0.2, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(4.6, 0.2, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
# Tùy chỉnh định dạng số trục y
ax.set_ylim([0, 1])  # Giới hạn trục y từ 0 đến 1
ax.yaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục y
ax.xaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục x


plt.show()

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., height, '%.2f' % height, ha='center', va='bottom', fontsize=8)

# Dữ liệu
methods = ['Euclide','KNN','SVC', 'LDA', 'LR']
pca_acc = [0.9799799930410579,0.9828983994432846,0.9487073764787752,0.9858176757132917,0.9829001391788449]
lle_acc = [0.9190970772442588,0.9353670842032011,0.9282794015309672,0.9228557759220599,0.6343475991649269]
kpca_acc = [0.9799799930410579,0.9828983994432846,0.9482898399443285,0.9858176757132917,0.9824852122477383]
ipca_acc = [0.9799808629088378,0.9795650661099513,0.9470407098121086,0.9858176757132917,0.9845676757132915]
#Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(10, 6))


 #Vẽ từng cột với màu sắc tương ứng
bar_width = 0.2
index = np.arange(len(methods))
opacity = 0.8

rects1 = ax.bar(index, pca_acc, bar_width, alpha=opacity,label='PCA')
rects2 = ax.bar(index + bar_width, lle_acc, bar_width, alpha=opacity, label='LLE')
rects3 = ax.bar(index + 2 * bar_width, kpca_acc, bar_width, alpha=opacity,label='KPCA')
rects4 = ax.bar(index + 3 * bar_width, ipca_acc, bar_width, alpha=opacity, label='IPCA')

rects1[0].set_facecolor('lightgray')
rects1[1].set_facecolor('gold')
rects1[2].set_facecolor('gold')
rects1[3].set_facecolor('lightgray')
rects1[4].set_facecolor('lightgray')
rects2[0].set_facecolor('lightgray')
rects2[1].set_facecolor('lightgray')
rects2[2].set_facecolor('lightgray')
rects2[3].set_facecolor('lightgray')
rects2[4].set_facecolor('lightgray')
rects3[0].set_facecolor('lightgray')
rects3[1].set_facecolor('lightgray')
rects3[2].set_facecolor('lightgray')
rects3[3].set_facecolor('gold')
rects3[4].set_facecolor('lightgray')
rects4[0].set_facecolor('gold')
rects4[1].set_facecolor('lightgray')
rects4[2].set_facecolor('lightgray')
rects4[3].set_facecolor('lightgray')
rects4[4].set_facecolor('gold')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

plt.xlabel('Methods')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison by Methods and Dimensionality Reduction Techniques in Set 4(Faces94)')
plt.xticks(index + 1.5 * bar_width, methods)
plt.tight_layout()
plt.text(0.6, 0.8, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(1.002, 0.8, 'PCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(2.002, 0.8, 'PCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(3.4, 0.8, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(4.6, 0.8, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
# Tùy chỉnh định dạng số trục y
ax.set_ylim([0.6, 1.2])  # Giới hạn trục y từ 0 đến 1
ax.yaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục y
ax.xaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục x


plt.show()

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., height, '%.2f' % height, ha='center', va='bottom', fontsize=8)

# Dữ liệu
methods = ['Euclide','KNN','SVC', 'LDA', 'LR']
pca_acc = [0.8535297710621814,0.7730033675972472,0.9197371902284152,0.797032202852822,0.80547014074662]
lle_acc = [0.7737752039013174,0.6459574134501376,0.6546546987943936,0.5754090275123875,0.5534347205482226]
kpca_acc = [0.8535287911599754,0.7747920157568274,0.9205011873148393,0.8041913683681037,0.8100694750663884]
ipca_acc = [0.8944328489350095,0.8389625448713552,0.939929055080303,0.8031667172949474,0.8093022116392783]

#Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(10, 6))


 #Vẽ từng cột với màu sắc tương ứng
bar_width = 0.2
index = np.arange(len(methods))
opacity = 0.8

rects1 = ax.bar(index, pca_acc, bar_width, alpha=opacity,label='PCA')
rects2 = ax.bar(index + bar_width, lle_acc, bar_width, alpha=opacity, label='LLE')
rects3 = ax.bar(index + 2 * bar_width, kpca_acc, bar_width, alpha=opacity,label='KPCA')
rects4 = ax.bar(index + 3 * bar_width, ipca_acc, bar_width, alpha=opacity, label='IPCA')

rects1[0].set_facecolor('lightgray')
rects1[1].set_facecolor('lightgray')
rects1[2].set_facecolor('lightgray')
rects1[3].set_facecolor('lightgray')
rects1[4].set_facecolor('lightgray')
rects2[0].set_facecolor('lightgray')
rects2[1].set_facecolor('lightgray')
rects2[2].set_facecolor('lightgray')
rects2[3].set_facecolor('lightgray')
rects2[4].set_facecolor('lightgray')
rects3[0].set_facecolor('lightgray')
rects3[1].set_facecolor('lightgray')
rects3[2].set_facecolor('lightgray')
rects3[3].set_facecolor('gold')
rects3[4].set_facecolor('gold')
rects4[0].set_facecolor('gold')
rects4[1].set_facecolor('gold')
rects4[2].set_facecolor('gold')
rects4[3].set_facecolor('lightgray')
rects4[4].set_facecolor('lightgray')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

plt.xlabel('Methods')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison by Methods and Dimensionality Reduction Techniques in Set 5(US Pres)')
plt.xticks(index + 1.5 * bar_width, methods)
plt.tight_layout()
plt.text(0.6, 0.6, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(1.6, 0.6, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(2.6, 0.6, 'IPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(3.4, 0.6, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
plt.text(4.4, 0.6, 'KPCA', rotation=55, ha='center', va='center', fontsize = 10, color='black')
# Tùy chỉnh định dạng số trục y
ax.set_ylim([0, 1.2])  # Giới hạn trục y từ 0 đến 1
ax.yaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục y
ax.xaxis.set_tick_params(length=0)  # Ẩn đường kẻ trục x


plt.show()

# %% [markdown]
# Họ và tên: Lê Hoàng Anh Đức
# Lớp: DSEB 63
# ID: 11219268

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('D:\\Năm 3 - HK1\\Visualize\\Ex\\autos.csv',encoding = 'latin')
df.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
#1
df.info()
# Lọc None value
# Sửa type của columns liên quan đến giá trị và thời gian
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
# #2
# import re
# for i in range(len(df.nunique().index)):
#     df.columns.values[i]=re.sub(r'(?<!^)(?=[A-Z])', '_', df.columns.values[i]).lower()
# df.columns

# %%
#3
df.nunique() #=> drop column 'neOfPictures' vì chỉ có 1 giá trị
# Out:
# dateCrawled            48213
# name                   38754
# seller                     2
# offerType                  2
# price                   2357
# abtest                     2
# vehicleType                8
# yearOfRegistration        97
# gearbox                    2
# powerPS                  448
# model                    245
# odometer                  13
# monthOfRegistration       13
# fuelType                   7
# brand                     40
# notRepairedDamage          2
# dateCreated               76
# nrOfPictures               1
# postalCode              7014
# lastSeen               39481
# dtype: int64

# %%
#5
m_count=df.groupby('model',as_index=True).nunique()[['dateCrawled']] > (0.1/100) * df.shape[0] 
othermodel=m_count[m_count['dateCrawled']==True].index #list model có observes >0.1%

# %%
# #5
# m_count=df.groupby('model',as_index=True).nunique()[['date_crawled']] > (0.1/100) * df.shape[0] 
# othermodel=m_count[m_count['date_crawled']==True].index #list model có observes >0.1%

# %%
other = df.set_index('model')
other.index
# Out:
# Index([  'andere',      '7er',     'golf',   'fortwo',    'focus',  'voyager',
#            'golf',     'golf',    'arosa',   'megane',
#        ...
#        'a_klasse',   'twingo',   'andere',        nan,       'a6',       'q5',
#           'astra',      '500',       'a3',   'vectra'],
#       dtype='object', name='model', length=50000)

# %%
for i in othermodel: #remove model have observes >0.1%
    other.drop(index = i,inplace=True)
other.reset_index()
# Out:
#         model          dateCrawled  \
# 0     voyager  2016-03-21 13:47:45
# 1         NaN  2016-03-15 01:41:36
# 2         NaN  2016-03-16 18:45:34
# 3         NaN  2016-04-01 12:06:20
# 4         NaN  2016-03-10 19:55:34
# ...       ...                  ...
# 5607     jazz  2016-03-27 20:51:39
# 5608      NaN  2016-03-31 22:48:48
# 5609      NaN  2016-04-02 16:38:23
# 5610     300c  2016-04-04 20:46:02
# 5611      NaN  2016-03-15 18:47:35
#
#                                                    name  seller offerType  \
# 0     Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...  privat   Angebot
# 1                          VW_Golf_Tuning_in_siber/grau  privat   Angebot
# 2                            Mercedes_A140_Motorschaden  privat   Angebot
# 3           Corvette_C3_Coupe_T_Top_Crossfire_Injection  privat   Angebot
# 4      Peugeot_Boxer_2_2_HDi_120_Ps_9_Sitzer_inkl_Klima  privat   Angebot
# ...                                                 ...     ...       ...
# ...

# %%
#6 find max null row
check = max(df.T.isna().sum())
check
# Out:
# 5

# %%
dfT=df.T # chuyển vị để fit với hàm .isna().sum()

# %%
dfT.loc['count_na']=df.T.isna().sum() # thêm hàng tính null 
df=dfT.T #chuyển vị lần nữa về ban đầu
df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
#7
#đổi type của data
df[['yearOfRegistration', 'monthOfRegistration', 'nrOfPictures', 'count_na']]=df[['yearOfRegistration', 'monthOfRegistration', 'nrOfPictures', 'count_na']].astype('int')
df[['dateCrawled','dateCreated','lastSeen']]=df[['dateCrawled','dateCreated','lastSeen']].astype('datetime64')
df[['name', 'powerPS', 'model','brand','postalCode', 'odometer','price']]=df[['name', 'powerPS', 'model','brand','postalCode', 'odometer','price']].astype('object')
df[['seller', 'offerType','abtest', 'gearbox', 'fuelType','vehicleType','notRepairedDamage']]=df[['seller', 'offerType','abtest', 'gearbox', 'fuelType','vehicleType','notRepairedDamage']].astype('category')
df
# Out:
#               dateCrawled                                               name  \
# 0     2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3     2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                   ...                                                ...
# 49995 2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996 2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997 2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998 2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999 2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
# #7
# #đổi type của data column
# df[['year_of_registration', 'month_of_registration', 'nr_of_pictures', 'count_na']]=df[['year_of_registration', 'month_of_registration', 'nr_of_pictures', 'count_na']].astype('int')
# df[['date_crawled','date_created','last_seen']]=df[['date_crawled','date_created','last_seen']].astype('datetime64')
# df[['name', 'power_p_s', 'model','brand','postal_code', 'odometer','price']]=df[['name', 'power_p_s', 'model','brand','postal_code', 'odometer','price']].astype('object')
# df[['seller', 'offer_type','abtest', 'gearbox', 'fuel_type','vehicle_type','not_repaired_damage']]=df[['seller', 'offer_type','abtest', 'gearbox', 'fuel_type','vehicle_type','not_repaired_damage']].astype('category')
# df

# %%
numeric_data=df._get_numeric_data() #lọc numeric data
numeric_data
# Out:
#        yearOfRegistration  monthOfRegistration  nrOfPictures  count_na
# 0                    2004                    3             0         0
# 1                    1997                    6             0         0
# 2                    2009                    7             0         0
# 3                    2007                    6             0         0
# 4                    2003                    7             0         0
# ...                   ...                  ...           ...       ...
# 49995                2011                    1             0         0
# 49996                1996                    5             0         0
# 49997                2014                   11             0         0
# 49998                2013                   11             0         0
# 49999                1996                    1             0         0
#
# [50000 rows x 4 columns]

# %%
a=dict(numeric_data.median())
a
# Out:
# {'yearOfRegistration': 2003.0,
#  'monthOfRegistration': 6.0,
#  'nrOfPictures': 0.0,
#  'count_na': 0.0}

# %%
numeric_data.fillna(a)
numeric_data.isna().sum()
# Out:
# yearOfRegistration     0
# monthOfRegistration    0
# nrOfPictures           0
# count_na               0
# dtype: int64

# %%
other_data=df.select_dtypes(include=['datetime64','object','category']) #lọc non-numeric data
other_data.head()
# Out:
#           dateCrawled                                               name  \
# 0 2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1 2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2 2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3 2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4 2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType    gearbox powerPS   model  \
# 0  privat   Angebot  $5,000  control         bus    manuell     158  andere
# 1  privat   Angebot  $8,500  control   limousine  automatik     286     7er
# 2  privat   Angebot  $8,990     test   limousine    manuell     102    golf
# 3  privat   Angebot  $4,350  control  kleinwagen  automatik      71  fortwo
# 4  privat   Angebot  $1,350     test       kombi    manuell       0   focus
#
# ...

# %%
b=dict(other_data.mode())

# %%
other_data.fillna(b)
# Out:
#               dateCrawled                                               name  \
# 0     2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3     2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                   ...                                                ...
# 49995 2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996 2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997 2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998 2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999 2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
df=pd.concat([numeric_data,other_data],axis=1) #gộp numeric và non-numeric data
df
# Out:
#        yearOfRegistration  monthOfRegistration  nrOfPictures  count_na  \
# 0                    2004                    3             0         0
# 1                    1997                    6             0         0
# 2                    2009                    7             0         0
# 3                    2007                    6             0         0
# 4                    2003                    7             0         0
# ...                   ...                  ...           ...       ...
# 49995                2011                    1             0         0
# 49996                1996                    5             0         0
# 49997                2014                   11             0         0
# 49998                2013                   11             0         0
# 49999                1996                    1             0         0
#
#               dateCrawled                                               name  \
# ...
